# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline

# %%
df=pd.read_csv("index_name_titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df=df[["Survived","Pclass","Sex","Age","SibSp","Parch","Fare","Embarked"]]

# %%
titanic_df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
x=titanic_df.drop("Survived",axis=1)
y=titanic_df[["Survived"]]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 331       1    male  45.5      0      0   28.5000        S
# 733       2    male  23.0      0      0   13.0000        S
# 382       3    male  32.0      0      0    7.9250        S
# 704       3    male  26.0      1      0    7.8542        S
# 813       3  female   6.0      4      2   31.2750        S
# ..      ...     ...   ...    ...    ...       ...      ...
# 106       3  female  21.0      0      0    7.6500        S
# 270       1    male   NaN      0      0   31.0000        S
# 860       3    male  41.0      2      0   14.1083        S
# 435       1  female  14.0      1      2  120.0000        S
# 102       1    male  21.0      0      1   77.2875        S
#
# [712 rows x 7 columns]

# %%
y_train
# Out:
#      Survived
# 331         0
# 733         0
# 382         0
# 704         0
# 813         0
# ..        ...
# 106         1
# 270         0
# 860         0
# 435         1
# 102         0
#
# [712 rows x 1 columns]

# %%
trf1=ColumnTransformer([("age_imp",SimpleImputer(),["Age"]),
                        ("embarked_imp",SimpleImputer(strategy="most_frequent"),["Embarked"])],remainder="passthrough")

# %%
trf2=ColumnTransformer([("ohe_sex_embark",OneHotEncoder(sparse_output=False,handle_unknown="ignore"),["Sex","Embarked"])],remainder="passthrough")

# %%
pipe=Pipeline([("trf1",trf1),("trf2",trf2)])

# %%
pipe.fit_transform(x_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\maner\OneDrive\Desktop\ML Practice\MLenv\Lib\site-packages\sklearn\utils\_indexing.py:446, in _get_column_indices(X, key)
#     445 try:
# --> 446     all_columns = X.columns
#     447 except AttributeError:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pipe.fit_transform(x_train)
#
# File c:\Users\maner\OneDrive\Desktop\ML Practice\MLenv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
# ...

# %%
trf1=ColumnTransformer([("age_imp",SimpleImputer(),["Age"]),
                        ("embarked_imp",SimpleImputer(strategy="most_frequent"),["Embarked"])],remainder="passthrough")

# %%
trf1.set_output(transform="pandas")
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('age_imp', SimpleImputer(), ['Age']),
#                                 ('embarked_imp',
#                                  SimpleImputer(strategy='most_frequent'),
#                                  ['Embarked'])])

# %%
trf2=ColumnTransformer([("ohe_sex_embark",OneHotEncoder(sparse_output=False,handle_unknown="ignore"),["Sex","Embarked"])],remainder="passthrough")

# %%
pipe=Pipeline([("trf1",trf1),("trf2",trf2)])

# %%
pipe.fit_transform(x_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\maner\OneDrive\Desktop\ML Practice\MLenv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
trf1=ColumnTransformer([("age_imp",SimpleImputer(),["Age"]),
                        ("embarked_imp",SimpleImputer(strategy="most_frequent"),["Embarked"])],remainder="passthrough")

# %%
trf1.set_output(transform="pandas")
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('age_imp', SimpleImputer(), ['Age']),
#                                 ('embarked_imp',
#                                  SimpleImputer(strategy='most_frequent'),
#                                  ['Embarked'])])

# %%
trf1.fit_transform(x_train)
# Out:
#      age_imp__Age embarked_imp__Embarked  remainder__Pclass remainder__Sex  \
# 331     45.500000                      S                  1           male
# 733     23.000000                      S                  2           male
# 382     32.000000                      S                  3           male
# 704     26.000000                      S                  3           male
# 813      6.000000                      S                  3         female
# ..            ...                    ...                ...            ...
# 106     21.000000                      S                  3         female
# 270     29.498846                      S                  1           male
# 860     41.000000                      S                  3           male
# 435     14.000000                      S                  1         female
# 102     21.000000                      S                  1           male
#
#      remainder__SibSp  remainder__Parch  remainder__Fare
# ...

# %%
trf2=ColumnTransformer([("ohe_embark_sex",OneHotEncoder(sparse_output=False,handle_unknown="ignore"),["embarked_imp__Embarked","remainder__Sex"])],remainder="passthrough")

# %%
pipe=Pipeline([("trf1",trf1),("trf2",trf2)])

# %%
pipe.fit_transform(x_train)
# Out:
# array([[  0.    ,   0.    ,   1.    , ...,   0.    ,   0.    ,  28.5   ],
#        [  0.    ,   0.    ,   1.    , ...,   0.    ,   0.    ,  13.    ],
#        [  0.    ,   0.    ,   1.    , ...,   0.    ,   0.    ,   7.925 ],
#        ...,
#        [  0.    ,   0.    ,   1.    , ...,   2.    ,   0.    ,  14.1083],
#        [  0.    ,   0.    ,   1.    , ...,   1.    ,   2.    , 120.    ],
#        [  0.    ,   0.    ,   1.    , ...,   0.    ,   1.    ,  77.2875]],
#       shape=(712, 10))

# %%
pipe.get_feature_names_out()
# Out:
# array(['ohe_embark_sex__embarked_imp__Embarked_C',
#        'ohe_embark_sex__embarked_imp__Embarked_Q',
#        'ohe_embark_sex__embarked_imp__Embarked_S',
#        'ohe_embark_sex__remainder__Sex_female',
#        'ohe_embark_sex__remainder__Sex_male', 'remainder__age_imp__Age',
#        'remainder__remainder__Pclass', 'remainder__remainder__SibSp',
#        'remainder__remainder__Parch', 'remainder__remainder__Fare'],
#       dtype=object)

# %%
pd.DataFrame(pipe.fit_transform(x_train),columns=pipe.get_feature_names_out(),index=x_train.index)
# Out:
#      ohe_embark_sex__embarked_imp__Embarked_C  \
# 331                                       0.0
# 733                                       0.0
# 382                                       0.0
# 704                                       0.0
# 813                                       0.0
# ..                                        ...
# 106                                       0.0
# 270                                       0.0
# 860                                       0.0
# 435                                       0.0
# 102                                       0.0
#
#      ohe_embark_sex__embarked_imp__Embarked_Q  \
# 331                                       0.0
# 733                                       0.0
# 382                                       0.0
# 704                                       0.0
# 813                                       0.0
# ..                                        ...
# 106                                       0.0
# ...
