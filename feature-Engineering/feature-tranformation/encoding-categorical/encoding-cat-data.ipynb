# %% [markdown]
# encoding categorical data

# %%
#means converting text (categorical data) into number so that machine learning model can understand it.

# %%
# categorical data have two types

# %%
#1> Ordinal categorical data
#2> Nominal categorical data

# %%
# 1> no order/no ranking ,categorical are just names
  #example:Gender:male,femmale
  #example:Color:red,green,blue
  #example:City:delhi,mumbai,kolkata
  
  
#used one hot encoding for nominal categorical data
#2> order /ranking 

#example :education:high school,graduate,post graduate,phd
#example:rating:bad,average,good,excellent
#example: size:small,medium,large,x-large

#used ordinal encoding for ordinal categorical data,for input column,and for output have categorical then used label encoding works only on y(output)column
