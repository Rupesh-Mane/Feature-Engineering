# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("Social_Network_Ads.csv")

# %%
df
# df.shape  #(400, 5)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
new_df=df.iloc[:,2:]

# %%
new_df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

x=new_df[["Age","EstimatedSalary"]]
y=new_df["Purchased"]

# %%
x
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train
# Out:
#      Age  EstimatedSalary
# 92    26            15000
# 223   60           102000
# 234   38           112000
# 232   40           107000
# 377   42            53000
# ..   ...              ...
# 323   48            30000
# 192   29            43000
# 117   36            52000
# 47    27            54000
# 172   26           118000
#
# [280 rows x 2 columns]

# %%
x_test
# Out:
#      Age  EstimatedSalary
# 132   30            87000
# 309   38            50000
# 341   35            75000
# 196   30            79000
# 246   35            50000
# ..   ...              ...
# 216   49            65000
# 259   45           131000
# 49    31            89000
# 238   46            82000
# 343   47            51000
#
# [120 rows x 2 columns]

# %%
y_train
# Out:
# 92     0
# 223    1
# 234    0
# 232    1
# 377    0
#       ..
# 323    1
# 192    0
# 117    0
# 47     0
# 172    0
# Name: Purchased, Length: 280, dtype: int64

# %%
y_test
# Out:
# 132    0
# 309    0
# 341    0
# 196    0
# 246    0
#       ..
# 216    0
# 259    1
# 49     0
# 238    0
# 343    1
# Name: Purchased, Length: 120, dtype: int64

# %%
x_train.shape,x_test.shape
# Out:
# ((280, 2), (120, 2))

# %%
#APPLYING STANDARDIZATION

from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
scaler.fit(x_train) # so basically here we are store mean,and sd of x_train in scaler object

#transform the train & test sets

x_train_scaled=scaler.transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
scaler.mean_ # mean of x_train
scaler.scale_ # sd of x_train
# Out:
# array([1.01999375e+01, 3.45792870e+04])

# %%
x_train
# Out:
#      Age  EstimatedSalary
# 92    26            15000
# 223   60           102000
# 234   38           112000
# 232   40           107000
# 377   42            53000
# ..   ...              ...
# 323   48            30000
# 192   29            43000
# 117   36            52000
# 47    27            54000
# 172   26           118000
#
# [280 rows x 2 columns]

# %%
x_train_scaled  #but here you return scaled value in numpy array format,so convert it into dataframe.
# Out:
# array([[-1.1631724 , -1.5849703 ],
#        [ 2.17018137,  0.93098672],
#        [ 0.0133054 ,  1.22017719],
#        [ 0.20938504,  1.07558195],
#        [ 0.40546467, -0.48604654],
#        [-0.28081405, -0.31253226],
#        [ 0.99370357, -0.8330751 ],
#        [ 0.99370357,  1.8563962 ],
#        [ 0.0133054 ,  1.24909623],
#        [-0.86905295,  2.26126285],
#        [-1.1631724 , -1.5849703 ],
#        [ 2.17018137, -0.80415605],
#        [-1.35925203, -1.46929411],
#        [ 0.40546467,  2.2901819 ],
#        [ 0.79762394,  0.75747245],
#        [-0.96709276, -0.31253226],
#        [ 0.11134522,  0.75747245],
#        [-0.96709276,  0.55503912],
#        [ 0.30742485,  0.06341534],
#        [ 0.69958412, -1.26686079],
#        [-0.47689368, -0.0233418 ],
#        [-1.7514113 ,  0.3526058 ],
#        [-0.67297331,  0.12125343],
#        [ 0.40546467,  0.29476771],
#        [-0.28081405,  0.06341534],
#        [-0.47689368,  2.2901819 ],
#        [ 0.20938504,  0.03449629],
# ...

# %%
x_train_scaled=pd.DataFrame(x_train_scaled,columns=x_train.columns)

# %%
x_train_scaled
# Out:
#           Age  EstimatedSalary
# 0   -1.163172        -1.584970
# 1    2.170181         0.930987
# 2    0.013305         1.220177
# 3    0.209385         1.075582
# 4    0.405465        -0.486047
# ..        ...              ...
# 275  0.993704        -1.151185
# 276 -0.869053        -0.775237
# 277 -0.182774        -0.514966
# 278 -1.065133        -0.457127
# 279 -1.163172         1.393691
#
# [280 rows x 2 columns]

# %%
x_train.describe()  # here you can see the mean and sd of x_train before scaling

#or you can round all values to 1 decimal place
# np.round(x_train.describe(),1)
# Out:
#               Age  EstimatedSalary
# count  280.000000       280.000000
# mean    37.864286     69807.142857
# std     10.218201     34641.201654
# min     18.000000     15000.000000
# 25%     30.000000     43000.000000
# 50%     37.000000     70500.000000
# 75%     46.000000     88000.000000
# max     60.000000    150000.000000

# %%
x_train_scaled.describe()  
#so here mean is e^-17 mean 0.0000000000000000348 Basically 0 and sd is 1.0
# Out:
#                 Age  EstimatedSalary
# count  2.800000e+02     2.800000e+02
# mean   3.489272e-17     6.344132e-17
# std    1.001791e+00     1.001791e+00
# min   -1.947491e+00    -1.584970e+00
# 25%   -7.710131e-01    -7.752370e-01
# 50%   -8.473441e-02     2.003677e-02
# 75%    7.976239e-01     5.261201e-01
# max    2.170181e+00     2.319101e+00

# %%
np.round(x_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean     0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.8             -0.8
# 50%     -0.1              0.0
# 75%      0.8              0.5
# max      2.2              2.3

# %%
#EFFECT OF SCALING

# %%
fig,ax=plt.subplots(nrows=2,ncols=1,figsize=(8,10))

ax[0].set_title("Before Scaling")
ax[0].scatter(x_train["Age"],x_train["EstimatedSalary"])

ax[1].set_title("After Scaling")
ax[1].scatter(x_train_scaled["Age"],x_train_scaled["EstimatedSalary"],color="red")


#nothing difference in point ,same as it is in both image only scalar changes

# %% [markdown]
# COMPARISION DISTRIBUTION

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(10,5))

#Before scaling

ax[0].set_title("Before Scaling")
sns.kdeplot(data=x_train,x="Age",ax=ax[0])

#After scaling 

ax[1].set_title("After Scaling")

sns.kdeplot(data=x_train_scaled,x="Age",ax=ax[1],color="red")

#same only dont change distribution only change scale
# Out:
# <Axes: title={'center': 'After Scaling'}, xlabel='Age', ylabel='Density'>
