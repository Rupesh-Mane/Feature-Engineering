# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv",usecols=["GarageQual","FireplaceQu","SalePrice"])

# %%
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
#using sklearn

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %%
x=df.drop(columns=["SalePrice"])
y=df["SalePrice"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.head()
# Out:
#      FireplaceQu GarageQual
# 254          NaN         TA
# 1066          TA         TA
# 638          NaN        NaN
# 799           TA         TA
# 380           Gd         TA

# %%
x_train.isnull().sum()
# Out:
# FireplaceQu    547
# GarageQual      64
# dtype: int64

# %%
si=SimpleImputer(strategy="most_frequent")

x_train_si=si.fit_transform(x_train)
x_test_si=si.transform(x_test)

# %%
x_train_df=pd.DataFrame(x_train_si,columns=x_train.columns,index=x_train.index)

# %%
x_train_df.head()
# Out:
#      FireplaceQu GarageQual
# 254           Gd         TA
# 1066          TA         TA
# 638           Gd         TA
# 799           TA         TA
# 380           Gd         TA

# %%
x_train_df.isnull().sum()
# Out:
# FireplaceQu    0
# GarageQual     0
# dtype: int64

# %%
si.statistics_
# Out:
# array(['Gd', 'TA'], dtype=object)

# %%
#check frequency of each category in GarageQual column
x_train["GarageQual"].value_counts(normalize=True)
# Out:
# GarageQual
# TA    0.951087
# Fa    0.032609
# Gd    0.011775
# Ex    0.002717
# Po    0.001812
# Name: proportion, dtype: float64

# %%
x_train_df["GarageQual"].value_counts(normalize=True)
# Out:
# GarageQual
# TA    0.953767
# Fa    0.030822
# Gd    0.011130
# Ex    0.002568
# Po    0.001712
# Name: proportion, dtype: float64

# %%
x_train["FireplaceQu"].value_counts(normalize=True)
# Out:
# FireplaceQu
# Gd    0.491143
# TA    0.405797
# Fa    0.043478
# Ex    0.033816
# Po    0.025765
# Name: proportion, dtype: float64

# %%
x_train_df["FireplaceQu"].value_counts(normalize=True)
# Out:
# FireplaceQu
# Gd    0.729452
# TA    0.215753
# Fa    0.023116
# Ex    0.017979
# Po    0.013699
# Name: proportion, dtype: float64

# %%
x_train["FireplaceQu"].value_counts(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
x_train_df["FireplaceQu"].value_counts(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
#using strategy="constant"

# %%
x_train.head()
# Out:
#      FireplaceQu GarageQual
# 254          NaN         TA
# 1066          TA         TA
# 638          NaN        NaN
# 799           TA         TA
# 380           Gd         TA

# %%
x_test.head()
# Out:
#      FireplaceQu GarageQual
# 892          NaN         TA
# 1105          TA         TA
# 413           Gd         TA
# 522           Gd         TA
# 1036          Ex         TA

# %%
si=SimpleImputer(strategy="constant",fill_value="missing")

x_train_si2=si.fit_transform(x_train)
x_test_si2=si.transform(x_test)

# %%
x_train_df2=pd.DataFrame(x_train_si2,columns=x_train.columns,index=x_train.index)

# %%
x_train_df2.head()
# Out:
#      FireplaceQu GarageQual
# 254      missing         TA
# 1066          TA         TA
# 638      missing    missing
# 799           TA         TA
# 380           Gd         TA

# %%
x_train_df2["FireplaceQu"].value_counts(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
x_train_df2["GarageQual"].value_counts(ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='GarageQual'>
